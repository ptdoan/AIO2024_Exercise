# %%
# Download data
# !gdown 1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq
# To: /content/advertising.csv
# 100% 4.06k/4.06k [00:00<00:00, 10.9MB/s]

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('/content/advertising.csv')
data = df.to_numpy()
data = data[:5]
data
# Out:
# array([[230.1,  37.8,  69.2,  22.1],
#        [ 44.5,  39.3,  45.1,  10.4],
#        [ 17.2,  45.9,  69.3,  12. ],
#        [151.5,  41.3,  58.5,  16.5],
#        [180.8,  10.8,  58.4,  17.9]])

# %%
# Cau 15
import numpy as np
import pandas as pd

df = pd.read_csv('/content/advertising.csv')
data = df.to_numpy()

sales_data = data[:,3]
sales_max = np.max(sales_data)
sales_idx = np.argmax(sales_data)
sales_max, sales_idx
# Out:
# (27.0, 175)

# %%
# Cau 16
TV_mean = data[:,0].mean()
TV_mean
# Out:
# 147.0425

# %%
# Cau 17
sales_counter = np.sum(data[:,3]>=20)
sales_counter
# Out:
# 40

# %%
# Cau 18
sales_cond = data[:,3]>=15
radio_data = data[:,1]
radio_cond = radio_data * sales_cond
radio_mean = np.sum(radio_cond)/np.sum(sales_cond)
radio_mean
# Out:
# 26.222935779816517

# %%
# Cau 19
Newspaper_data = data[:,2]
Newspaper_mean = Newspaper_data.mean()

Newspaper_cond1 = Newspaper_data >= Newspaper_mean
sales_data = data[:,3]
sales_cond = sales_data * Newspaper_cond1
sales_sum = np.sum(sales_cond)
sales_sum
# Out:
# 1405.1

# %%
# Cau 20
sales_data = data[:,3]
sales_mean = sales_data.mean()
sales_mean

score_sales = np.where(
    sales_data < sales_mean,
    "Bad",
    np.where(sales_data > sales_mean,"Good","Average")
)
score_sales[7:10]
# Out:
# array(['Bad', 'Bad', 'Good'], dtype='<U7')

# %%
# Cau 21
sales_data = data[:,3]
sales_mean = sales_data.mean()
sub_mean = sales_data - sales_mean
sub_abs = abs(sales_data - sales_mean)
average_idx = np.argmax(sub_abs)
sales_average = sales_data[average_idx]
score_sales = np.where(
    sales_data < sales_mean,
    "Bad",
    np.where(sales_data > sales_average,"Good","Average")
)
score_sales[7:10]
# Out:
# array(['Bad', 'Bad', 'Good'], dtype='<U7')
