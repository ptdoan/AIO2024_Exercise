# %%
# Download image
# !gdown 1i9dqan21DjQoG5Q_VEvm0LrVwAlXD0vB
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1i9dqan21DjQoG5Q_VEvm0LrVwAlXD0vB
# To: /content/dog.jpeg
# 100% 33.7k/33.7k [00:00<00:00, 48.9MB/s]

# %%
import matplotlib.pyplot as plt

img = plt.imread('/content/dog.jpeg')
plt.imshow(img)

# %%
import numpy as np

# the lightness method
def color2grayscale1(vector):
  return np.max(vector)*0.5 + np.min(vector)*0.5

# the average method
def color2grayscale2(vector):
  return np.sum(vector)/3

# the luminosity method
def color2grayscale3(vector):
  return vector[0]*0.21 + vector[1]*0.72 + vector[2]*0.07

# %%
# Cau 12
import matplotlib.pyplot as plt

img = plt.imread('/content/dog.jpeg')
gray_img_01 = np.apply_along_axis(color2grayscale1, 2, img)

print(gray_img_01[0,0])

plt.imshow(gray_img_01,cmap=plt.get_cmap('gray'))
plt.imshow(gray_img_01)
# Out:
# 102.5

# %%
# Cau 13
import matplotlib.pyplot as plt

img = plt.imread('/content/dog.jpeg')
gray_img_01 = np.apply_along_axis(color2grayscale2, 2, img)

print(gray_img_01[0,0])

plt.imshow(gray_img_01,cmap=plt.get_cmap('gray'))
plt.imshow(gray_img_01)
# Out:
# 107.66666666666667

# %%
# Cau 14
import matplotlib.pyplot as plt

img = plt.imread('/content/dog.jpeg')
gray_img_01 = np.apply_along_axis(color2grayscale3, 2, img)

print(gray_img_01[0,0])

plt.imshow(gray_img_01,cmap=plt.get_cmap('gray'))
plt.imshow(gray_img_01)
# Out:
# 126.22999999999999
